# %%
import numpy as np

seed = 9658  # replace with your own Drexel ID last 4 digits if needed
rng = np.random.default_rng(seed)

n_readings = 200
timestamps = rng.uniform(0.0, 10.0, size=n_readings)

sensor_a = rng.normal(loc=25.0, scale=3.0, size=n_readings)
sensor_b = rng.normal(loc=27.0, scale=4.5, size=n_readings)

# Sort timestamps and apply the same ordering to the sensor readings so the pairs stay aligned
order = np.argsort(timestamps)
timestamps = timestamps[order]
sensor_a = sensor_a[order]
sensor_b = sensor_b[order]

timestamps, sensor_a, sensor_b
# Out:
# (array([0.01568539, 0.02541888, 0.17288684, 0.17451781, 0.19164794,
#         0.24430982, 0.25234011, 0.26339447, 0.41292285, 0.41456016,
#         0.47140096, 0.52235832, 0.53514111, 0.57553236, 0.67738895,
#         0.83004965, 0.8415383 , 0.87135725, 0.95266382, 0.960056  ,
#         0.96852251, 0.98017711, 0.99444648, 1.01519366, 1.03222988,
#         1.04178173, 1.07537253, 1.07951635, 1.09513385, 1.14621014,
#         1.18891984, 1.24181675, 1.26926692, 1.40145771, 1.4504971 ,
#         1.46509978, 1.65745883, 1.93295196, 1.93624117, 1.96823092,
#         2.04226141, 2.04342129, 2.15938961, 2.17246948, 2.19295674,
#         2.19867815, 2.26005855, 2.26458009, 2.2895496 , 2.34647583,
#         2.39221021, 2.45015713, 2.54761654, 2.58146712, 2.58502015,
#         2.79081243, 2.79394091, 2.79549614, 2.80071513, 2.82986397,
#         2.90422514, 2.95119166, 2.98854169, 3.00021618, 3.04475012,
#         3.19382673, 3.29487837, 3.41173152, 3.51687635, 3.53906768,
#         3.72786997, 3.76509227, 3.84686795, 3.90824686, 3.95724458,
#         3.99977322, 4.06235153, 4.07213271, 4.13536444, 4.15447562,
#         4.23114581, 4.23541564, 4.24173478, 4.29285535, 4.30082091,
#         4.3664574 , 4.41944459, 4.42650715, 4.46733689, 4.48227127,
#         4.53512481, 4.55924871, 4.71185199, 4.74466628, 4.81085057,
#         4.84743402, 4.86421941, 4.90287681, 5.04857709, 5.09134392,
#         5.22571588, 5.24525329, 5.24701795, 5.32212247, 5.35762533,
#         5.47168142, 5.553187  , 5.61369133, 5.62457988, 5.7777417 ,
#         5.80129242, 5.83757476, 5.84228459, 6.01049284, 6.02203886,
#         6.07437699, 6.11812573, 6.20170083, 6.25625402, 6.26026771,
#         6.33758717, 6.36135255, 6.37128524, 6.39306478, 6.44212401,
#         6.45171394, 6.46355995, 6.63922617, 6.67794132, 6.74368899,
#         6.77929275, 6.80530598, 6.94491967, 7.07119862, 7.07240316,
#         7.07721403, 7.12412232, 7.14499082, 7.15705022, 7.17463358,
#         7.17913446, 7.18149158, 7.3086694 , 7.35333003, 7.40237637,
#         7.40866657, 7.46939652, 7.49211434, 7.49215385, 7.68667647,
#         7.69691009, 7.70217894, 7.70301278, 7.8335588 , 7.98820859,
#         8.04153084, 8.0556512 , 8.0639567 , 8.06734813, 8.07521568,
#         26.69006986, 26.42989289, 32.87491838, 34.6793418 , 27.67123412,
#         26.94227149, 22.61919982, 33.15434826, 31.70289799, 21.46876676,
#         25.34026418, 30.6101199 , 22.62304378, 32.81310321, 19.79122156,
#         26.52320967, 27.90443103, 25.23390736, 28.31196166, 26.04067027,
#         31.33125036, 36.38891084, 18.03688906, 33.743838  , 27.96841032,
#         17.33422431, 23.80159676, 27.63736813, 23.10660575, 27.28598499,
#         21.75245589, 26.62726404, 26.6137563 , 29.2726219 , 32.6098255 ,
#         26.04225677, 25.27978965, 24.72777809, 30.67495145, 26.5647754 ,
#         26.19747953, 27.67368221, 26.29282276, 33.56130461, 26.87602323,
#         31.5800259 , 23.14068888, 35.06649318, 27.98214775, 22.01640988,
#         28.33931492, 36.99685172, 24.41573456, 31.84669533, 30.05174475]))

# %%
# Scatter plot: sensor reading (y-axis) vs timestamp in seconds (x-axis).
# Color Sensor A points blue and Sensor B points orange.
# Add axis labels with units, a title, and a legend.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.scatter(timestamps, sensor_a, color="tab:blue", alpha=0.7, label="Sensor A")
plt.scatter(timestamps, sensor_b, color="tab:orange", alpha=0.7, label="Sensor B")
plt.title("Sensor Temperature Readings vs Time")
plt.xlabel("Time (s)")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
# Overlaid histogram of Sensor A and Sensor B temperature distributions.
# Use 30 bins, alpha=0.5 for transparency so both distributions are visible.
# Add vertical dashed lines at each sensor's mean.
# Include a legend labeling each sensor.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(sensor_a, bins=30, color="tab:blue", alpha=0.5, label="Sensor A")
plt.hist(sensor_b, bins=30, color="tab:orange", alpha=0.5, label="Sensor B")

mean_a = sensor_a.mean()
mean_b = sensor_b.mean()
plt.axvline(mean_a, color="tab:blue", linestyle="--", linewidth=2, label="Mean A")
plt.axvline(mean_b, color="tab:orange", linestyle="--", linewidth=2, label="Mean B")

plt.title("Temperature Distribution for Sensor A and Sensor B")
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.4)
plt.show()

# %%
# Side-by-side box plot comparing Sensor A and Sensor B distributions.
# Label x-axis with sensor names, y-axis with "Temperature (deg C)".
# Add a horizontal dashed line at the overall mean of both sensors combined.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.boxplot([sensor_a, sensor_b], labels=["Sensor A", "Sensor B"], patch_artist=True,
            boxprops=dict(facecolor="lightgray", color="black"),
            medianprops=dict(color="red"),
            whiskerprops=dict(color="black"),
            capprops=dict(color="black"))

overall_mean = np.concatenate([sensor_a, sensor_b]).mean()
plt.axhline(overall_mean, color="blue", linestyle="--", linewidth=1.5,
            label=f"Overall Mean = {overall_mean:.2f} °C")

plt.title("Sensor Temperature Distribution Comparison")
plt.ylabel("Temperature (deg C)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()
# Out:
# /tmp/ipykernel_4757/458581464.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([sensor_a, sensor_b], labels=["Sensor A", "Sensor B"], patch_artist=True,
